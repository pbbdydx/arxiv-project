# %%
import sys
sys.path.append("../scripts")
from fetch_data import get_data

# %%
# load dataframe 
# data is already downloaded and saved as a json tile
df = pd.DataFrame('/data/arxiv-data.json')
# Out:
# Gathering cs.AI articles...
#   0%|                                                    | 0/20 [00:09<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 # load dataframe
# ----> 3 df = get_data(arxiv_categories, 20, False)
#
# File c:\Users\pb601\OneDrive\Desktop\arxiv_nlp_project\notebooks\../scripts\fetch_data.py:38, in get_data(categories, max_res, save_json, filename, verbose)
#      30 print(f"Gathering {cat} articles...") if verbose else None
#      32 search = arxiv.Search(
#      33     query = f"cat:{cat}",
#      34     max_results = max_res,
#      35     sort_by = arxiv.SortCriterion.SubmittedDate
#      36 )
# ---> 38 for result in tqdm(search.results(), total = max_res, disable = not verbose, ncols = 80):
#      39     temp_pdf = f"temp/{result.get_short_id()}.pdf"
#      40     try:
#
# ...
